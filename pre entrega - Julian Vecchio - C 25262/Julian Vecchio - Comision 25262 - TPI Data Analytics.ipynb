# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import numpy as np
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Etapa 1 - Paso 1

# %%
clientes = pd.read_csv("/content/drive/MyDrive/cursos/📊 ciencia de datos/talento tech/Analisis de datos/pre_entrega/datasets/clientes.csv")
marketing = pd.read_csv("/content/drive/MyDrive/cursos/📊 ciencia de datos/talento tech/Analisis de datos/pre_entrega/datasets/marketing.csv")
ventas = pd.read_csv("/content/drive/MyDrive/cursos/📊 ciencia de datos/talento tech/Analisis de datos/pre_entrega/datasets/ventas.csv")

# %%
ventas['fecha_venta'] = pd.to_datetime(ventas['fecha_venta'],format= '%d/%m/%Y')

# %%
ventas['precio'] = ventas['precio'].str.replace('$','').str.replace(',','.').astype(float)

# %%
ventas['ventas_totales'] = ventas['cantidad'] * ventas['precio']
ventas_mensuales = ventas.groupby(ventas['fecha_venta'].dt.to_period('M'))['ventas_totales'].sum()

# %%
ventas_mensuales
# Out:
# fecha_venta
# 2024-01    129604.99
# 2024-02    118672.44
# 2024-03    136779.15
# 2024-04    128430.69
# 2024-05    143727.25
# 2024-06    108480.17
# 2024-07    116229.97
# 2024-08    119680.15
# 2024-09    115787.85
# 2024-10    112117.13
# 2024-11    119951.79
# 2024-12    117631.94
# Freq: M, Name: ventas_totales, dtype: float64

# %% [markdown]
# # Etapa 1 - Paso 2

# %%
print(f"VENTAS POR MES: \n {'-'*15}\n {ventas_mensuales}")
# Out:
# VENTAS POR MES:
#  ---------------
#  fecha_venta
# 2024-01    129604.99
# 2024-02    118672.44
# 2024-03    136779.15
# 2024-04    144380.10
# 2024-05    143727.25
# 2024-06    108480.17
# 2024-07    116229.97
# 2024-08    119680.15
# 2024-09    115787.85
# 2024-10    112117.13
# 2024-11    119951.79
# 2024-12    117631.94
# Freq: M, Name: ventas_totales, dtype: float64

# %% [markdown]
# # Etapa 1 - PASO 3

# %%
estructura = {}
for index,row in ventas.iterrows():
  estructura[row['id_venta']] = {
      'producto' : row['producto'],
      'precio_unitario' : row['precio'],
      'cantidad_vendida' : row['cantidad'],
      }

print(estructura)
# Out:
# {792: {'producto': 'Cuadro decorativo', 'precio_unitario': '$69.94', 'cantidad_vendida': 5.0}, 811: {'producto': 'Lámpara de mesa', 'precio_unitario': '$105.10', 'cantidad_vendida': 5.0}, 1156: {'producto': 'Secadora', 'precio_unitario': '$97.96', 'cantidad_vendida': 3.0}, 1372: {'producto': 'Heladera', 'precio_unitario': '$114.35', 'cantidad_vendida': 8.0}, 1546: {'producto': 'Secadora', 'precio_unitario': '$106.21', 'cantidad_vendida': 4.0}, 1697: {'producto': 'Horno eléctrico', 'precio_unitario': '$35.35', 'cantidad_vendida': 9.0}, 1710: {'producto': 'Plancha de vapor', 'precio_unitario': '$65.43', 'cantidad_vendida': 2.0}, 2959: {'producto': 'Proyector', 'precio_unitario': '$88.17', 'cantidad_vendida': 9.0}, 318: {'producto': 'Rincón de plantas', 'precio_unitario': '$79.86', 'cantidad_vendida': 11.0}, 419: {'producto': 'Candelabro', 'precio_unitario': '$66.11', 'cantidad_vendida': 8.0}, 1374: {'producto': 'Aspiradora', 'precio_unitario': '$95.90', 'cantidad_vendida': 5.0}, 1571: {'producto': 'Freidora eléctrica', 'precio_unitario': '$111.18', 'cantidad_vendida': 1.0}, 1814: {'producto': 'Aspiradora', 'precio_unitario': '$70.91', 'cantidad_vendida': 2.0}, 2769: {'producto': 'Proyector', 'precio_unitario': '$43.62', 'cantidad_vendida': 11.0}, 2794: {'producto': 'Tablet', 'precio_unitario': '$67.97', 'cantidad_vendida': 9.0}, 2824: {'producto': 'Tablet', 'precio_unitario': '$74.09', 'cantidad_vendida': 5.0}, 446: {'producto': 'Cortinas', 'precio_unitario': '$62.10', 'cantidad_vendida': 4.0}, 630: {'producto': 'Adorno de pared', 'precio_unitario': '$71.99', 'cantidad_vendida': 9.0}, 794: {'producto': 'Jarrón decorativo', 'precio_unitario': '$96.97', 'cantidad_vendida': 7.0}, 882: {'producto': 'Cuadro decorativo', 'precio_unitario': '$101.92', 'cantidad_vendida': 9.0}, 969: {'producto': 'Candelabro', 'precio_unitario': '$90.70', 'cantidad_vendida': 12.0}, 1445: {'producto': 'Lavadora', 'precio_unitario': '$28.41', 'cantidad_vendida': 10.0}, 1971: {'producto': 'Freidora eléctrica', 'precio_unitario': '$122.25', 'cantidad_vendida': 11.0}, 2209: {'producto': 'Proyector', 'precio_unitario': '$32.15', 'cantidad_vendida': 1.0}, 256: {'producto': 'Cortinas', 'precio_unitario': '$86.82', 'cantidad_vendida': 8.0}, 606: {'producto': 'Cortinas', 'precio_unitario': '$106.66', 'cantidad_vendida': 11.0}, 704: {'producto': 'Jarrón decorativo', 'precio_unitario': '$57.22', 'cantidad_vendida': 9.0}, 1362: {'producto': 'Heladera', 'precio_unitario': '$109.49', 'cantidad_vendida': 11.0}, 2155: {'producto': 'Auriculares', 'precio_unitario': '$84.80', 'cantidad_vendida': 10.0}, 2947: {'producto': 'Cámara digital', 'precio_unitario': '$107.78', 'cantidad_vendida': 3.0}, 1495: {'producto': 'Lavadora', 'precio_unitario': '$38.99', 'cantidad_vendida': 6.0}, 1572: {'producto': 'Cafetera', 'precio_unitario': '$61.40', 'cantidad_vendida': 9.0}, 2180: {'producto': 'Consola de videojuegos', 'precio_unitario': '$102.57', 'cantidad_vendida': 9.0}, 2487: {'producto': 'Cámara digital', 'precio_unitario': '$50.76', 'cantidad_vendida': 3.0}, 2603: {'producto': 'Smartphone', 'precio_unitario': '$87.05', 'cantidad_vendida': 5.0}, 2885: {'producto': 'Auriculares', 'precio_unitario': '$100.40', 'cantidad_vendida': 6.0}, 17: {'producto': 'Elementos de cerámica', 'precio_unitario': '$108.48', 'cantidad_vendida': 11.0}, 183: {'producto': 'Espejo decorativo', 'precio_unitario': '$82.76', 'cantidad_vendida': 8.0}, 560: {'producto': 'Adorno de pared', 'precio_unitario': '$57.62', 'cantidad_vendida': 6.0}, 632: {'producto': 'Cuadro decorativo', 'precio_unitario': '$30.49', 'cantidad_vendida': 12.0}, 699: {'producto': 'Candelabro', 'precio_unitario': '$34.23', 'cantidad_vendida': 12.0}, 1150: {'producto': 'Plancha de vapor', 'precio_unitario': '$33.63', 'cantidad_vendida': 10.0}, 1400: {'producto': 'Plancha de vapor', 'precio_unitario': '$26.91', 'cantidad_vendida': 5.0}, 1496: {'producto': 'Secadora', 'precio_unitario': '$95.33', 'cantidad_vendida': 11.0}, 1524: {'producto' ...

# %% [markdown]
# # Etapa 1 - PASO 4

# %%
marketing.head()
# Out:
#    id_campanha         producto  canal  costo fecha_inicio   fecha_fin
# 0           74  Adorno de pared     TV   4.81   20/03/2024  03/05/2024
# 1           12           Tablet   RRSS   3.40   26/03/2024  13/05/2024
# 2           32  Lámpara de mesa  Email   5.54   28/03/2024  20/04/2024
# 3           21       Smartphone   RRSS   6.37   29/03/2024  16/05/2024
# 4           58         Alfombra  Email   4.25   31/03/2024  05/05/2024

# %%
clientes.head()
# Out:
#    id_cliente               nombre  edad         ciudad  ingresos
# 0           1      Aloysia Screase    44  Mar del Plata  42294.68
# 1           2  Kristina Scaplehorn    25        Posadas  24735.04
# 2           3       Filip Castagne    50    Resistencia  35744.85
# 3           4          Liuka Luard    39   Bahía Blanca  27647.96
# 4           5        Dore Cockshtt    28        Rosario  28245.65

# %%
ventas.head()
# Out:
#    id_venta           producto   precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   $69.94       5.0  02/01/2024
# 1       811    Lámpara de mesa  $105.10       5.0  02/01/2024
# 2      1156           Secadora   $97.96       3.0  02/01/2024
# 3      1372           Heladera  $114.35       8.0  02/01/2024
# 4      1546           Secadora  $106.21       4.0  02/01/2024
#
#            categoria
# 0         Decoración
# 1         Decoración
# 2  Electrodomésticos
# 3  Electrodomésticos
# 4  Electrodomésticos

# %%
ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3035 entries, 0 to 3034
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     3035 non-null   int64
#  1   producto     3035 non-null   object
#  2   precio       3033 non-null   object
#  3   cantidad     3033 non-null   float64
#  4   fecha_venta  3035 non-null   object
#  5   categoria    3035 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 142.4+ KB

# %%
marketing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_campanha   90 non-null     int64
#  1   producto      90 non-null     object
#  2   canal         90 non-null     object
#  3   costo         90 non-null     float64
#  4   fecha_inicio  90 non-null     object
#  5   fecha_fin     90 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.3+ KB

# %%
clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 0 to 566
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_cliente  567 non-null    int64
#  1   nombre      567 non-null    object
#  2   edad        567 non-null    int64
#  3   ciudad      567 non-null    object
#  4   ingresos    567 non-null    float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 22.3+ KB

# %%
marketing.describe()
# Out:
#        id_campanha      costo
# count    90.000000  90.000000
# mean     45.500000   4.928667
# std      26.124701   0.947750
# min       1.000000   2.950000
# 25%      23.250000   4.372500
# 50%      45.500000   4.900000
# 75%      67.750000   5.562500
# max      90.000000   7.390000

# %%
ventas.describe()
# Out:
#           id_venta     cantidad
# count  3035.000000  3033.000000
# mean   1499.851400     6.496538
# std     866.465379     3.457250
# min       1.000000     1.000000
# 25%     748.500000     3.000000
# 50%    1502.000000     7.000000
# 75%    2249.500000     9.000000
# max    3000.000000    12.000000

# %%
clientes.describe()
# Out:
#        id_cliente        edad      ingresos
# count  567.000000  567.000000    567.000000
# mean   284.000000   37.940035  34668.739012
# std    163.823075   10.202885  12974.531446
# min      1.000000   20.000000    170.290000
# 25%    142.500000   30.000000  26015.240000
# 50%    284.000000   37.000000  35066.830000
# 75%    425.500000   43.000000  42457.100000
# max    567.000000   81.000000  88053.010000

# %% [markdown]
# # Etapa 1 - PASO 5

# %%
ventas.isnull().sum()
# Out:
# id_venta       0
# producto       0
# precio         2
# cantidad       2
# fecha_venta    0
# categoria      0
# dtype: int64

# %%
marketing.isnull().sum()
# Out:
# id_campanha     0
# producto        0
# canal           0
# costo           0
# fecha_inicio    0
# fecha_fin       0
# dtype: int64

# %%
clientes.isnull().sum()
# Out:
# id_cliente    0
# nombre        0
# edad          0
# ciudad        0
# ingresos      0
# dtype: int64

# %%
ventas.duplicated().sum()
# Out:
# np.int64(35)

# %%
marketing.duplicated().sum()
# Out:
# np.int64(0)

# %%
clientes.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Etapa 2 - PASO 1

# %%
ventas.drop_duplicates(inplace=True)

# %%
ventas.dropna(inplace=True)

# %%
print(f"DUPLICADOS: {ventas.duplicated().sum()}\n")
print(f"NULOS: \n{ventas.isnull().sum()}")
# Out:
# DUPLICADOS: 0
#
# NULOS:
# id_venta       0
# producto       0
# precio         0
# cantidad       0
# fecha_venta    0
# categoria      0
# dtype: int64

# %% [markdown]
# # Etapa 2 - PASO 2

# %%
#Se seleccionan solamente los primeros 5 productos mas vendidos
ventas_producto = ventas.groupby(ventas['producto'])['ventas_totales'].sum().sort_values(ascending=False)
ventas_producto.head(5)
# Out:
# producto
# Lámpara de mesa      82276.38
# Auriculares          74175.58
# Microondas           72562.89
# Cafetera             59607.31
# Cuadro decorativo    54297.60
# Name: ventas_totales, dtype: float64

# %% [markdown]
# # Etapa 2 - PASO 3

# %%
#Se seleccionan solamente los primeros 5 productos mas vendidos
ventas_categoria = ventas.groupby(ventas['categoria'])['ventas_totales'].sum().sort_values(ascending=False)
ventas_categoria
# Out:
# categoria
# Electrodomésticos    505299.63
# Electrónica          482577.80
# Decoración           479216.09
# Name: ventas_totales, dtype: float64

# %% [markdown]
# # Etapa 2 - PASO 4

# %%
venta_mark = pd.merge(
    ventas,
    marketing,
    on='producto',
    how='outer'
    )
venta_mark.head()
# Out:
#    id_venta         producto  precio  cantidad fecha_venta   categoria  \
# 0       630  Adorno de pared   71.99       9.0  2024-01-04  Decoración
# 1       630  Adorno de pared   71.99       9.0  2024-01-04  Decoración
# 2       630  Adorno de pared   71.99       9.0  2024-01-04  Decoración
# 3       560  Adorno de pared   57.62       6.0  2024-01-07  Decoración
# 4       560  Adorno de pared   57.62       6.0  2024-01-07  Decoración
#
#    ventas_totales  id_campanha  canal  costo fecha_inicio   fecha_fin
# 0          647.91           74     TV   4.81   20/03/2024  03/05/2024
# 1          647.91           44  Email   5.08   13/04/2024  10/05/2024
# 2          647.91           14   RRSS   4.16   22/10/2024  21/12/2024
# 3          345.72           74     TV   4.81   20/03/2024  03/05/2024
# 4          345.72           44  Email   5.08   13/04/2024  10/05/2024
